# %%
# CELL1 – 2 marks
################################################################################################################################
#  libraries needed for the coursework
# %pylab inline
import pandas as pd
from pandas import Series, DataFrame
from scipy import stats
import statsmodels.api as sm
################################################################################################################################

unis = pd.read_excel('./2018-QS-World-University-Rankings-Top200.xlsx', index_col='Rank')

unis
# Out:
# Populating the interactive namespace from numpy and matplotlib
#                                   Institution Name        Location  \
# Rank
# 1     MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)    United States
# 2                              STANFORD UNIVERSITY   United States
# 3                               HARVARD UNIVERSITY   United States
# 4     CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)   United States
# 5                          UNIVERSITY OF CAMBRIDGE  United Kingdom
# ...                                            ...             ...
# 196                 TECHNISCHE UNIVERSITÄT DRESDEN         Germany
# 197                           TEXAS A&M UNIVERSITY   United States
# 198              UNIVERSITAT AUTÓNOMA DE BARCELONA           Spain
# 199               TECNOLÓGICO DE MONTERREY (ITESM)          Mexico
# 200                          MAASTRICHT UNIVERSITY     Netherlands
#
#       Academic Reputation  Employer Reputation  Faculty Student  \
# Rank
# 1                   100.0                100.0            100.0
# 2                   100.0                100.0            100.0
# 3                   100.0                100.0             98.3
# 4                    99.5                 85.4            100.0
# 5                   100.0                100.0            100.0
# ...                   ...                  ...              ...
# 196                  41.5                 77.0              6.8
# 197                  69.7                 54.1             10.2
# 198                  72.1                 41.5             19.0
# 199                  42.8                 84.9             77.1
# 200                  30.8                 39.0             35.4
#
#       Citations per Faculty  International Faculty  International Students  \
# Rank
# 1                      99.9                  100.0                    96.1
# 2                      99.4                   99.6                    72.7
# 3                      99.9                   96.5                    75.2
# 4                     100.0                   93.4                    89.2
# 5                      78.3                   97.4                    97.7
# ...                     ...                    ...                     ...
# 196                    79.0                   92.4                    38.5
# 197                    57.0                   10.4                    15.5
# 198                    43.7                   21.5                    28.6
# 199                     3.7                   98.4                    23.2
# 200                    73.3                   95.9                   100.0
#
#       Overall Score
# Rank
# 1             100.0
# 2              98.7
# 3              98.4
# 4              97.7
# 5              95.6
# ...             ...
# 196            48.1
# 197            48.1
# 198            48.1
# 199            48.0
# 200            47.9
#
# [200 rows x 9 columns]

# %%
# CELL2 – 2 marks

qsuk = pd.read_excel('./2018-QS-World-University-Rankings-Top200.xlsx', index_col=2)

qsukdf = qsuk[(qsuk.Location == 'United Kingdom')]
# qsukdfn = qsukdf.drop('Location', axis=1)
del qsukdf.index.name

qsukdfn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-a6610a6320e4> in <module>
#       5 qsukdf = qsuk[(qsuk.Location == 'United Kingdom')]
#       6 # qsukdfn = qsukdf.drop('Location', axis=1)
# ----> 7 del qsukdf.index.Rank
#       8
#       9 qsukdfn
#
# AttributeError: Rank

# %%
# CELL3 – 5 marks

# %%
# CELL4 – 9 marks

# %%
# CELL5 – 7 marks

# %%
# CELL6 – 8 marks

# %%
# CELL7 – 14 marks

# %%
# CELL8 – 13 marks

# %%
import scipy
print(scipy.__version__)
