# %%
# CELL1 – 2 marks
################################################################################################################################
#  libraries needed for the coursework
# %pylab inline
import pandas as pd
from pandas import Series, DataFrame
from scipy import stats
import statsmodels.api as sm
################################################################################################################################

unis = pd.read_excel('./2018-QS-World-University-Rankings-Top200.xlsx', index_col='Rank')
unis = unis.rename_axis(None, axis=0)

display(unis)
# Out:
# Populating the interactive namespace from numpy and matplotlib
#                                  Institution Name        Location  \
# 1    MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)    United States
# 2                             STANFORD UNIVERSITY   United States
# 3                              HARVARD UNIVERSITY   United States
# 4    CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)   United States
# 5                         UNIVERSITY OF CAMBRIDGE  United Kingdom
# ..                                            ...             ...
# 196                TECHNISCHE UNIVERSITÄT DRESDEN         Germany
# 197                          TEXAS A&M UNIVERSITY   United States
# 198             UNIVERSITAT AUTÓNOMA DE BARCELONA           Spain
# 199              TECNOLÓGICO DE MONTERREY (ITESM)          Mexico
# 200                         MAASTRICHT UNIVERSITY     Netherlands
#
#      Academic Reputation  Employer Reputation  Faculty Student  \
# ...

# %%
# CELL2 – 2 marks

qsuk = pd.read_excel('./2018-QS-World-University-Rankings-Top200.xlsx', index_col=2)

qsukdf = qsuk[(qsuk.Location == 'United Kingdom')]
qsukdfn = qsukdf.reset_index()
qsukdfn.index = qsukdfn.index + 1

qsdf = qsukdfn.drop(['Location', 'Rank'], axis=1)

display(qsdf)
# Out:
#                                      Institution Name  Academic Reputation  \
# 1                             UNIVERSITY OF CAMBRIDGE                100.0
# 2                                UNIVERSITY OF OXFORD                100.0
# 3                     UCL (UNIVERSITY COLLEGE LONDON)                 99.7
# 4                             IMPERIAL COLLEGE LONDON                 99.4
# 5                         KING'S COLLEGE LONDON (KCL)                 92.8
# 6                             UNIVERSITY OF EDINBURGH                 99.1
# 7                        THE UNIVERSITY OF MANCHESTER                 97.4
# 8   LONDON SCHOOL OF ECONOMICS AND POLITICAL SCIEN...                 90.3
# 9                               UNIVERSITY OF BRISTOL                 85.7
# 10                          THE UNIVERSITY OF WARWICK                 83.5
# 11                              UNIVERSITY OF GLASGOW                 80.4
# ...

# %%
# CELL3 – 5 marks

import numpy as np

unis = pd.read_excel('./2018-QS-World-University-Rankings-Top200.xlsx', index_col='Rank')
unis = unis.rename_axis(None, axis=0)

ukunis = unis[(unis.Location == 'United Kingdom')]

avg = np.mean(ukunis['Academic Reputation'])
err = 1.96 * numpy.std(ukunis['Academic Reputation']) / np.sqrt(len(ukunis['Academic Reputation']))
err_lb = avg - err
err_ub = avg + err

print('Analysis of Academic Reputation for UK Universities in the world\'s top 200')
print('mean of Academic Reputation = ', round(avg, 2))
print('minimum of Academic Reputation = ', min(ukunis['Academic Reputation']))
print('maximum of Academic Reputation = ', max(ukunis['Academic Reputation']))
print('standard deviation of Academic Reputation = ', round(stats.tstd(ukunis['Academic Reputation']),2))
print('95%% confidence interval of Academic Reputation = (%s, %s)' % (round(err_lb, 2), round(err_ub, 2)))
# Out:
# Analysis of Academic Reputation for UK Universities in the world's top 200
# mean of Academic Reputation =  70.51
# minimum of Academic Reputation =  39.4
# maximum of Academic Reputation =  100.0
# standard deviation of Academic Reputation =  21.45
# 95% confidence interval of Academic Reputation = (62.71, 78.31)

# %%
# CELL4 – 9 marks

import matplotlib.pyplot as plt
import numpy as np

def calc_err(data, avg):
    return 1.96 * numpy.std(data) / np.sqrt(len(data))

unis = pd.read_excel('./2018-QS-World-University-Rankings-Top200.xlsx', index_col='Rank')

x = ['United States', 'United Kingdom', 'Canada', 'Australia', 'Netherlands', 'Germany']
y = []
y_conf = []

for location in x:
    cpf = unis.loc[unis['Location'] == location]['Citations per Faculty']
    avg = np.mean(cpf)
    
    y.append(avg)
    y_conf.append(calc_err(cpf, avg))

# Create bar chart
plt.figure(figsize=(12,6))

plt.bar(x, y, yerr=y_conf, ecolor='black')

plt.xlabel("Location", fontsize=12)
plt.ylabel("Mean Citations per Faculty", fontsize=12)
plt.title("Mean Citations per Faculty vs Location", fontsize=16)

plt.show()

# %%
# CELL5 – 7 marks
unis = pd.read_excel('./2018-QS-World-University-Rankings-Top200.xlsx', index_col='Rank')

def get_country(n): return unis.loc[unis['Location'] == n]['Citations per Faculty']

# Get pandas data
us_cpf = get_country('United States')
nl_cpf = get_country('Netherlands')

# Normality tests
def normality(name, data):
    res = stats.shapiro(data)
    print('%s Citations Per Faculty Normality Test:\n - Statistic: %s\n - P-Value: %s' % (name, round(res[0], 5), round(res[1], 5)))
    print('Is %s Citations Per Faculty normal? %s\n' % (name, res[1] > 0.05))
    
normality('United States', us_cpf)
normality('Netherlands', nl_cpf)

mwu_test = stats.mannwhitneyu(us_cpf, nl_cpf, alternative='two-sided')
print('Is the observed difference significant?', mwu_test[1] < 0.05)
print()

# Significance tests
us_mean = np.mean(us_cpf)
nl_mean = np.mean(nl_cpf)
print('Mean for the United States: %s' % round(us_mean, 2))
print('Mean for the Netherlands: %s' % round(nl_mean, 2))
print('Difference between the United States and Netherlands mean: %s' % round(abs(us_mean - nl_mean), 2))

# print(stats.ttest_ind(us_cpf, nl_cpf))

print('\nConcluding statement:')
print(' - The Netherlands fits the Normal distribution well however the US does not.')
print(' - The observed statistical difference is not significant.')
print(' - The observed p-value is greater than 5% for the Netherlands')
# Out:
# United States Citations Per Faculty Normality Test:
#  - Statistic: 0.91527
#  - P-Value: 0.0023
# Is United States Citations Per Faculty normal? False
#
# Netherlands Citations Per Faculty Normality Test:
#  - Statistic: 0.92817
#  - P-Value: 0.43016
# Is Netherlands Citations Per Faculty normal? True
#
# Is the observed difference significant? False
#
# Mean for the United States: 75.74
# Mean for the Netherlands: 75.49
# Difference between the United States and Netherlands mean: 0.25
#
# Concluding statement:
#  - The Netherlands fits the Normal distribution well however the US does not.
#  - The observed statistical difference is not significant.
#  - The observed p-value is greater than 5% for the Netherlands

# %%
# CELL6 – 8 marks
import matplotlib.pyplot as plt

# Load model data into x, y coordinate lists
x = []
y = []

def get_image_data(i):
    img = plt.imread('./Model/m%s.png' % i) * 255
    mimg = matrix(img)
    return [mimg.mean(), 11-i]

for i in range(1, 11, 1):
    tmp = get_image_data(i)
    x.append(tmp[0])
    y.append(tmp[1])

# Plot data as scatter chart
plt.figure(figsize=(10,5))
plt.ylim([0, 11])
plt.xlabel("Average Pixel Intensity", fontsize=12)
plt.ylabel("Image Quality", fontsize=12)
plt.title("API vs IQ for the Model dataset", fontsize=16)
#plt.xlim(xmin=0, xmax=255)

plt.scatter(x, y, marker='o')

plt.show()

print('The Pearson linear correlation coefficient between Average Pixel Intensity and Image Quality for the model dataset is:')
print('r = %s' % stats.pearsonr(x, y)[0])
print('This is an extremely strong positive correlation because the pearson value is greater than 0.8')
# Out:
# The Pearson linear correlation coefficient between Average Pixel Intensity and Image Quality for the model dataset is:
# r = 0.8681160544727963
# This is an extremely strong positive correlation because the pearson value is greater than 0.8

# %%
# CELL7 – 14 marks

import matplotlib.pyplot as plt

# Load model data into x, y coordinate lists
x = []
y = []

def get_image_data(i):
    img = plt.imread('./Model/m%s.png' % i) * 255
    mimg = matrix(img)
    return [mimg.mean(), 11-i]

for i in range(1, 11, 1):
    tmp = get_image_data(i)
    x.append(tmp[0])
    y.append(tmp[1])

# Calculate linear regression data
mc = stats.linregress(x, y)
line = list(map(lambda xval: mc[0] * xval + mc[1], x))

# Visualise the data
plt.figure(figsize=(10,5))
plt.ylim([0, 12])
plt.xlabel("Average Pixel Intensity", fontsize=12)
plt.ylabel("Image Quality", fontsize=12)
plt.title("API vs IQ", fontsize=16)

plt.scatter(x, y, marker='o')
plt.plot(x, line, 'r-', label='solid')
plt.show()

# Print what the line on the plot indicates
print('The line shown above indicates the linear regression model')
print('In the following equations,\n - The y variable indicates Image Quality\n - The x variable indicates Average Pixel Intensity')
print()
print('This linear equation represents the regression model shown above:')

# Print linear equation
mcr = tuple(list(map(lambda x: round(x, 2), mc))[0:2])
print("y=%sx%s" % mcr)

# Print MSE
y_bar = list(map(lambda x: mc[0] * x + mc[1], x))
mse = np.square(np.subtract(y, y_bar)).mean()
print('Mean Squared Error (MSE) = %s' % round(mse, 2))

print()
print('This linear equation represents the regression model rotated by 2 degrees around the point where image quality is equal to 5.5')

# Find value
rotate_deg = 2
rotate_origin_x = 5.5
deg = np.deg2rad(360 - rotate_deg)
deg_cos = np.cos(deg)
deg_sin = np.sin(deg)

mc_rot = [(mc[0] * deg_cos + deg_sin) / (deg_cos - mc[0] * deg_sin)]
mc_rot.append(rotate_origin_x - ((rotate_origin_x - mc[1]) / mc[0]) * mc_rot[0])

line_rot = list(map(lambda xval: mc_rot[0] * xval + mc_rot[1], x))

mcr_rot = tuple(list(map(lambda x: round(x, 2), mc_rot)))
print("y=%sx%s" % mcr_rot)

# Print MSE of rotated line
y_rotbar = list(map(lambda x: mc_rot[0] * x + mc_rot[1], x))
mse_rot = np.square(np.subtract(y, y_rotbar)).mean()
print('Mean Squared Error (MSE) = %s' % round(mse_rot, 2))
# Out:
# The line shown above indicates the linear regression model
# In the following equations,
#  - The y variable indicates Image Quality
#  - The x variable indicates Average Pixel Intensity
#
# This linear equation represents the regression model shown above:
# y=0.64x-101.45
# Mean Squared Error (MSE) = 2.03
#
# This linear equation represents the regression model rotated by 2 degrees around the point where image quality is equal to 5.5
# y=0.6x-93.43
# Mean Squared Error (MSE) = 2.07

# %%
# CELL8 – 13 marks

qdf = pd.read_excel('./Q_scores.xlsx')
qdf.reset_index()

import matplotlib.pyplot as plt

# Load model data
image_data = []
x = []
y = []
y_bar = []

def get_image_data(i):
    image_name = 't%s' % i
    image_file = image_name + '.png'
    img = plt.imread('./Test/%s' % image_file) * 255
    mimg = matrix(img)
    qual = qdf[qdf['Image'] == image_name].Quality
    
    return image_file, qual, mimg.mean()

for i in range(1, 11, 1):
    name, quality, mean = get_image_data(i)
    qs = int(quality)
    pq = round((mc[0] * mean) + mc[1], 2)
    
    image_data.append([name, qs, pq])
    x.append(mean)
    y.append(qs)
    y_bar.append(pq)

# Construct and display a tabular data structure
df = pd.DataFrame(image_data, columns=['Name', 'True Quality', 'Predicted Quality'])

display(df)

# Print the MSE
mse = np.square(np.subtract(y, y_bar)).mean()
print('Mean Squared Error (MSE) = %s\n' % round(mse, 2))

# Print a statement on the effectiveness of the model
print('The mean squared error is far higher on the test dataset, which would indicate the model is not suitable and should be adjusted.\n')

# Find a new equation
print('The following linear equation is an adjusted linear regression model that better fits the test data.')
tmc = stats.linregress(x, y)
tline = list(map(lambda xval: tmc[0] * xval + tmc[1], x))
tmcr = tuple(list(map(lambda x: round(x, 2), tmc))[0:2])
print('\ny=%sx%s' % tmcr)

# Find MSE of new equation
mse = np.square(np.subtract(y, tline)).mean()
print('Mean Squared Error (MSE) = %s' % round(mse, 2))
# Out:
#       Name  True Quality  Predicted Quality
# 0   t1.png            10              19.11
# 1   t2.png             9              16.19
# 2   t3.png             8              14.36
# 3   t4.png             7              13.28
# 4   t5.png             6              12.39
# 5   t6.png             5              11.95
# 6   t7.png             4              11.73
# 7   t8.png             3              11.52
# 8   t9.png             2              11.56
# 9  t10.png             1              11.37
# Mean Squared Error (MSE) = 63.5
#
# The mean squared error is far higher on the test dataset, which would indicate the model is not suitable and should be adjusted.
#
# The following linear equation is an adjusted linear regression model that better fits the test data.
#
# y=0.67x-114.0
# Mean Squared Error (MSE) = 1.93

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.5.2
